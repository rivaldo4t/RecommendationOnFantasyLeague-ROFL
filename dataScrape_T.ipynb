# %% [markdown]
# # Verify data collection methods and code in general

# %% [markdown]
# # Data Scrape

# %%
import numpy as np
import pandas as pd
gameWeekData = pd.read_csv('data/2016-17/players/Aaron_Cresswell/gw.csv')
historyData = pd.read_csv('data/2016-17/players/Aaron_Cresswell/history.csv')
print list(gameWeekData)
print
print list(historyData)
gameWeekData['total_points'].plot()
# Out:
# ['assists', 'attempted_passes', 'big_chances_created', 'big_chances_missed', 'bonus', 'bps', 'clean_sheets', 'clearances_blocks_interceptions', 'completed_passes', 'creativity', 'dribbles', 'ea_index', 'element', 'errors_leading_to_goal', 'errors_leading_to_goal_attempt', 'fixture', 'fouls', 'goals_conceded', 'goals_scored', 'ict_index', 'id', 'influence', 'key_passes', 'kickoff_time', 'kickoff_time_formatted', 'loaned_in', 'loaned_out', 'minutes', 'offside', 'open_play_crosses', 'opponent_team', 'own_goals', 'penalties_conceded', 'penalties_missed', 'penalties_saved', 'recoveries', 'red_cards', 'round', 'saves', 'selected', 'tackled', 'tackles', 'target_missed', 'team_a_score', 'team_h_score', 'threat', 'total_points', 'transfers_balance', 'transfers_in', 'transfers_out', 'value', 'was_home', 'winning_goals', 'yellow_cards']
#
# ['assists', 'bonus', 'bps', 'clean_sheets', 'creativity', 'ea_index', 'element_code', 'end_cost', 'goals_conceded', 'goals_scored', 'ict_index', 'id', 'influence', 'minutes', 'own_goals', 'penalties_missed', 'penalties_saved', 'red_cards', 'saves', 'season', 'season_name', 'start_cost', 'threat', 'total_points', 'yellow_cards']

# %%
import glob
path = 'data/2016-17/players'
filenames = glob.glob(path + "/*/gw.csv")
all_p_gwData = (pd.read_csv(f) for f in filenames)
p_gwData = pd.concat(all_p_gwData, keys=[i for i in range(683)])
p_gwData[:35]

# not multidimensional, but multiindexed
# https://pandas.pydata.org/pandas-docs/stable/merging.html
# Out:
#       assists  attempted_passes  big_chances_created  big_chances_missed  \
# 0 0         0                 7                    0                   0
#   1         0                30                    0                   0
#   2         0                24                    0                   0
#   3         0                31                    0                   0
#   4         0                23                    0                   0
#   5         0                36                    0                   0
#   6         0                16                    0                   0
#   7         0                21                    0                   0
#   8         0                47                    0                   1
#   9         0                14                    0                   0
#   10        0                35                    0                   0
#   11        0                19                    0                   0
#   12        0                33                    0                   0
#   13        0                43                    0                   0
#   14        0                39                    0                   0
#   15        0                 0                    0                   0
#   16        0                39                    0                   0
#   17        0                37                    0                   0
#   18        0                15                    0                   0
#   19        0                46                    0                   0
#   20        0                 2                    0                   0
#   21        0                 0                    0                   0
#   22        0                 0                    0                   0
#   23        0                22                    0                   0
#   24        0                35                    0                   0
#   25        0                45                    0                   0
#   26        0                33                    0                   0
#   27        1                30                    0                   0
#   28        0                37                    0                   0
#   29        0                26                    0                   0
#   30        0                38                    0                   0
#   31        0                26                    0                   0
#   32        0                52                    0                   0
#   33        0                47                    0                   0
#   34        0                49                    0                   0
#
#       bonus  bps  clean_sheets  clearances_blocks_interceptions  \
# 0 0       0    3             0                                1
#   1       0   12             0                                5
#   2       0   24             1                                2
#   3       0    9             0                                3
#   4       0    5             0                                2
#   5       0    5             0                                8
#   6       0    3             1                                4
#   7       0    9             0                                1
#   8       0    3             0                                2
#   9       0    1             0                                4
#   10      0    6             0                                3
#   11      1   28             0                                6
#   12      0    7             0                                1
#   13      0   12             0                                4
#   14      0    3             1                                2
#   15      0    0             0                                0
#   16      0    9             0                                2
#   17      0    5             1                                2
#   18      0    4             0                                1
#   19      0   13             1                                2
#   20      0   -7             0                                0
#   21      0    0             0                                0
#   22      0    0             0                                0
#   23      0    6             0                                4
#   24      0   14             0                                5
#   25      0    5             1                                0
#   26      0    9             0                                3
#   27      0   21             1                                2
#   28      0    7             1                                3
#   29      0    9             0                                6
#   30      0   15             0                                0
#   31      0   10             1                                4
#   32      0   15             0                                3
#   33      0   14             0                                5
#   34      0    7             0                                1
#
#       completed_passes  creativity      ...       team_h_score  threat  \
# 0 0                  6         1.5      ...                  1     0.0
#   1                 23        12.7      ...                  3     1.0
#   2                 18         2.2      ...                  2    25.0
#   3                 24        21.3      ...                  0    11.0
#   4                 19         2.7      ...                  3     3.0
#   5                 28         1.7      ...                  2     2.0
#   6                 12         2.0      ...                  0     2.0
#   7                 19         1.2      ...                  3    35.0
#   8                 45        16.5      ...                  4     7.0
#   9                 11         2.2      ...                  1    22.0
#   10                25        18.1      ...                  2    39.0
#   11                10        12.3      ...                  3     9.0
#   12                29         5.7      ...                  1     9.0
#   13                29         2.9      ...                  2     0.0
#   14                24        14.5      ...                  1     4.0
#   15                 0         0.0      ...                  4     0.0
#   16                33         4.1      ...                  2     1.0
#   17                25        12.2      ...                  1     3.0
#   18                12         0.8      ...                  2     1.0
#   19                38        16.3      ...                  1    33.0
#   20                 0         0.0      ...                  2     0.0
#   21                 0         0.0      ...                  1     0.0
#   22                 0         0.0      ...                  1     0.0
#   23                20         5.6      ...                  3     7.0
#   24                27        11.4      ...                  2     0.0
#   25                38         3.3      ...                  0     2.0
#   26                23        15.8      ...                  0     0.0
#   27                23        17.7      ...                  1     9.0
#   28                27         2.5      ...                  0     0.0
#   29                19         1.7      ...                  3     0.0
#   30                33        12.9      ...                  0     2.0
#   31                17         3.1      ...                  0     0.0
#   32                43         3.4      ...                  2     8.0
#   33                36         2.8      ...                  2    16.0
#   34                39         3.3      ...                  1     8.0
#
#       total_points  transfers_balance  transfers_in  transfers_out  value  \
# 0 0              1               1286          1488            202     55
#   1              2                -73           127            200     55
#   2              8               -145            99            244     54
#   3              2                472           595            123     54
#   4              2                241           393            152     54
#   5              1                -66           169            235     54
#   6              3               -143            79            222     54
#   7              2                -97           103            200     54
#   8              2                -98            64            162     54
#   9              2               -126            49            175     54
#   10             1                -23            83            106     54
#   11             8                -55            65            120     54
#   12             1                565           628             63     54
#   13             2                293           446            153     54
#   14             2                645           853            208     54
#   15             0               -687           127            814     54
#   16             1               -169           124            293     54
#   17             3                113           477            364     54
#   18             2               -136           153            289     54
#   19             3                  8           205            197     54
#   20            -2                -30           117            147     54
#   21             0               -586            27            613     53
#   22             0               -249            13            262     53
#   23             2                  8            62             54     53
#   24             2                 52            84             32     53
#   25             3                  8            48             40     53
#   26             2                 -4            35             39     53
#   27             6                 32            51             19     53
#   28             3                163           204             41     53
#   29             2                 -7            71             78     53
#   30             1                -25            64             89     53
#   31             3                 -9            53             62     53
#   32             2                 41           110             69     53
#   33             2                -37            42             79     53
#   34             2                 64           121             57     53
#
#       was_home  winning_goals  yellow_cards
# 0 0       True              0             0
#   1      False              0             0
#   2       True              1             0
#   3       True              0             0
#   4      False              0             0
#   5       True              0             1
#   6      False              0             0
#   7       True              0             0
#   8      False              0             0
#   9       True              0             0
#   10     False              0             1
#   11      True              0             0
#   12     False              0             1
#   13     False              0             0
#   14      True              0             1
#   15      True              0             0
#   16     False              0             1
#   17      True              0             0
#   18     False              0             0
#   19      True              0             0
#   20     False              0             0
#   21      True              0             0
#   22     False              0             0
#   23     False              0             0
#   24     False              0             0
#   25     False              0             0
#   26      True              0             0
#   27      True              0             0
#   28     False              0             0
#   29     False              0             0
#   30      True              0             1
#   31     False              0             0
#   32      True              0             0
#   33     False              0             0
#   34      True              0             0
#
# [35 rows x 54 columns]

# %%
path = 'data/2016-17/players'
filenames = glob.glob(path + "/*/history.csv")
all_p_hData = (pd.read_csv(f).mean() for f in filenames)
p_hData = pd.concat(all_p_hData, keys=[i for i in range(683)])
print p_hData
# Out:
# 0    assists                  1.000000
#      bonus                    1.000000
#      bps                    286.000000
#      clean_sheets             9.000000
#      creativity             234.400000
#      ea_index                 0.000000
#      element_code         83314.000000
#      end_cost                53.000000
#      goals_conceded          47.000000
#      goals_scored             2.000000
#      ict_index               77.400000
#      id                    7340.000000
#      influence              284.600000
#      minutes               2691.000000
#      own_goals                0.000000
#      penalties_missed         0.000000
#      penalties_saved          0.000000
#      red_cards                1.000000
#      saves                    0.000000
#      season                  11.000000
#      start_cost              55.000000
#      threat                 259.000000
#      total_points            76.000000
#      yellow_cards             6.000000
# 1    assists                  7.000000
#      bonus                    8.000000
#      bps                    343.000000
#      clean_sheets             9.000000
#      creativity             505.100000
#      ea_index                 0.000000
#                              ...
# 681  saves                    0.000000
#      season                  10.000000
#      start_cost              56.666667
#      threat                   0.000000
#      total_points            54.333333
#      yellow_cards             3.666667
# 682  assists                  0.000000
#      bonus                    0.000000
#      bps                      0.000000
#      clean_sheets             0.000000
#      creativity               0.000000
#      ea_index                 0.000000
#      element_code        168717.000000
#      end_cost                40.000000
#      goals_conceded           0.000000
#      goals_scored             0.000000
#      ict_index                0.000000
#      id                    6867.000000
#      influence                0.000000
#      minutes                  0.000000
#      own_goals                0.000000
#      penalties_missed         0.000000
#      penalties_saved          0.000000
#      red_cards                0.000000
#      saves                    0.000000
#      season                  11.000000
#      start_cost              40.000000
#      threat                   0.000000
#      total_points             0.000000
#      yellow_cards             0.000000
# Length: 16392, dtype: float64

# %%
mat = np.zeros((683,9))
for i in range(683):
    mat[i][0] = p_hData[i]['assists']
    mat[i][1] = p_hData[i]['goals_scored']
    mat[i][2] = p_hData[i]['bonus']
    mat[i][3] = p_hData[i]['clean_sheets']
    mat[i][4] = p_hData[i]['creativity']
    mat[i][5] = p_hData[i]['saves']
    mat[i][6] = p_hData[i]['influence']
    mat[i][7] = p_hData[i]['start_cost']
    mat[i][8] = 0 if p_hData[i]['minutes'] == 0 else p_hData[i]['total_points'] / p_hData[i]['minutes']

# %%
from sklearn import linear_model
regr = linear_model.LinearRegression(normalize=True)
regr.fit(mat[:,0:7], mat[:,8])
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=True)

# %%
print regr.coef_
print regr.intercept_
# Out:
# [ 1.86498515e-03  1.84792236e-03  1.90717954e-04 -2.31108928e-03
#  -4.91922858e-06  5.62941097e-05 -2.76038775e-06]
# 0.04832643265578758

# %% [markdown]
# # Player Position Data embed

# %%
player_id = pd.read_csv('data/2016-17/player_idlist.csv')
player_pos = pd.read_csv('data/2016-17_pos_clean.csv')
n = 0
m = 0
for i in player_id.index:
    fname = player_id['first_name'][i]
    sname = player_id['second_name'][i]
    pname = fname + ' ' + sname
    n += 1
    for j in player_pos.index:
        if player_pos['player'][j] == pname:
#             print pname, player_pos['position'][j]
            m += 1
            player_id.loc[i, 'position'] = player_pos['position'][j]
# print n, m
player_id.to_csv('2016-17_player_position.csv')

# %%
player_id = pd.read_csv('data/2017-18/player_idlist.csv')
player_pos = pd.read_csv('data/2017-18_pos_clean.csv')
n = 0
m = 0
for i in player_id.index:
    fname = player_id['first_name'][i]
    sname = player_id['second_name'][i]
    pname = fname + ' ' + sname
    n += 1
    for j in player_pos.index:
        if player_pos['player'][j] == pname:
#             print pname, player_pos['position'][j]
            m += 1
            player_id.loc[i, 'position'] = player_pos['position'][j]
# print n, m
player_id.to_csv('2017-18_player_position.csv')

# %% [markdown]
# # Match Result field addition

# %%
path = 'data/2016-17/players'
filenames = glob.glob(path + "/*/gw.csv")
for f in filenames:
    a = pd.read_csv(f)
    b = a['team_h_score'] - a['team_a_score']
    for i in a.index:
        if a.loc[i, 'was_home'] == True:
            if b[i] < 0:
                a.loc[i, 'match_result'] = -1
            elif b[i] == 0:
                a.loc[i, 'match_result'] = 0
            else:
                a.loc[i, 'match_result'] = 1
        else:
            if b[i] < 0:
                a.loc[i, 'match_result'] = 1
            elif b[i] == 0:
                a.loc[i, 'match_result'] = 0
            else:
                a.loc[i, 'match_result'] = -1
    a.to_csv(f[:-4] + "_match_result.csv")

# %% [markdown]
# # Training and Prediction

# %%
features = ['assists', 'bonus', 'goals_scored', 'start_cost', 'end_cost','minutes', 'total_points']

# %%
import unicodedata

import glob
path = 'data/2016-17/players'
filenames = glob.glob(path + "/*/history.csv")
p_name = pd.read_csv('data/2016-17/player_idlist.csv', encoding='utf-8')

fname1 = [unicodedata.normalize('NFD', x).encode('ascii', 'ignore') for x in p_name['first_name']]
sname1 = [unicodedata.normalize('NFD', x).encode('ascii', 'ignore') for x in p_name['second_name']]


fname = pd.DataFrame({'':fname1})
sname = pd.DataFrame({'':sname1})

#print sname

pname = fname + '_' + sname

print pname
# Out:
#
# 0                 David_Ospina
# 1                    Petr_Cech
# 2            Laurent_Koscielny
# 3              Per_Mertesacker
# 4     Gabriel Armando_de Abreu
# 5              Hector_Bellerin
# 6                 Kieran_Gibbs
# 7              Mathieu_Debuchy
# 8               Carl_Jenkinson
# 9                Nacho_Monreal
# 10              Calum_Chambers
# 11              Alexis_Sanchez
# 12                Theo_Walcott
# 13                  Mesut_Ozil
# 14            Santiago_Cazorla
# 15                Aaron_Ramsey
# 16               Jack_Wilshere
# 17     Alex_Oxlade-Chamberlain
# 18                Serge_Gnabry
# 19            Francis_Coquelin
# 20                  Alex_Iwobi
# 21              Mohamed_Elneny
# 22               Joel_Campbell
# 23                Granit_Xhaka
# 24              Olivier_Giroud
# 25               Danny_Welbeck
# 26                 Yaya_Sanogo
# 27                Takuma_Asano
# 28                 Artur_Boruc
# 29               Adam_Federici
# ..                         ...
# 653             Connor_Roberts
# 654            Matthew_Willock
# 655              Axel_Tuanzebe
# 656   Damian Emiliano_Martinez
# 657               Joe_Williams
# 658               Dion_Pereira
# 659                 Matt_Macey
# 660              James_Husband
# 661  Joel Dinis_Castro Pereira
# 662  Eduardo_Dos Reis Carvalho
# 663               Moses_Makasi
# 664             Nathan_Holland
# 665             Rhian_Brewster
# 666            Scott_McTominay
# 667                 Angus_Gunn
# 668           Demetri_Mitchell
# 669              Elliott_Moore
# 670              Filip_Lesniak
# 671            Samuel_Shashoua
# 672           Zachary_Dearnley
# 673              Joshua_Harrop
# 674                Daniel_Kemp
# 675               Daniel_Batty
# 676             Aaron_Ramsdale
# 677        Matthew_Worthington
# 678               Sam_Surridge
# 679                Angel_Gomes
# 680              Kieran_O'Hara
# 681            Gerhard_Tremmel
# 682             Rene_Gilmartin
#
# [683 rows x 1 columns]

# %%
import pandas as pd
player_avg_history = pd.DataFrame(index = pname, columns = features)
player_avg_history[:5]

print player_avg_history.index[0]
# Out:
# ('David_Ospina',)

# %%
##Shubham
#print pname.values
pname_1617 = pname

pname_pos_team_1617 = pd.read_csv('data/Player_Pos_Team_2016-17.csv', skiprows=None, encoding='utf-8')

fname1 = [unicodedata.normalize('NFD', x).encode('ascii', 'ignore') for x in pname_pos_team_1617['FirstName']]
sname1 = [unicodedata.normalize('NFD', x).encode('ascii', 'ignore') for x in pname_pos_team_1617['Surname']]
fname = pd.DataFrame({'name':fname1})
sname = pd.DataFrame({'name':sname1})

pname_pos_team_1617_name = fname + '_' + sname
#print pname_pos_team

unknown_players = []

count = 0
for st in pname_1617.values:
    if st not in pname_pos_team_1617_name.values:
        #if st not in pname_pos_team_1718_name.values:
        print st
        unknown_players.append(st)
        count += 1

print count


# count = 0
# for i in pname_pos_team.index:
#     player_name = pname_pos_team.loc[i]['FirstName'] + '_' + pname_pos_team.loc[i]['Surname']
#     if(player_name in pname.values):
#         #print player_name
#         count += 1
#     else:
#         for i in range(len(pname)):
#             if player_name in pname[i]:
#                 print i, pname[i], player_name

# print count
# Out:
# ['Daniel_Drinkwater']
# ['Emilio_Nsue Lopez']
# ['Mateusz_Hewelt']
# ['Alex_Pike']
# ['Elliot_Embleton']
# ['Omar_Elabdellaoui']
# ['Joleon_Lescott']
# ['Andrea_Ranocchia']
# ['Giedrius_Arlauskis']
# ['Kamil_Grosicki']
# ['Matthew_Willock']
# ['Joshua_Harrop']
# ['Angel_Gomes']
# ['Gerhard_Tremmel']
# ['Rene_Gilmartin']
# 15

# %%
#print type(p_gwData.index)#.loc[0]
d = 0

for i,j in p_gwData.groupby(level=0):
    player_minutes_sum = j['minutes'].sum()
    if player_avg_history.index[i] in unknown_players:
        if player_minutes_sum == 0:
            unknown_players.remove(player_avg_history.index[i])
            d += 1
print d

print list(unknown_players)
# Out:
# 0
# [array(['Fernando Francisco_Reges'], dtype=object), array(['Manuel_Agudo Duran'], dtype=object), array(['Jose Angel_Esmoris Tasende'], dtype=object), array(['Fabio Pereira_da Silva'], dtype=object), array(['Michael_Simoes Domingues'], dtype=object), array(['Ben_Wynter'], dtype=object), array(['Jake_Hesketh'], dtype=object), array(['George_Honeyman'], dtype=object), array(['Jeff_Reine-Adelaide'], dtype=object), array(['Olufela_Olomola'], dtype=object), array(['Raphael_Spiegel'], dtype=object), array(['Daniel_James'], dtype=object), array(['Thibaud_Verlinden'], dtype=object), array(['Ryan_Allsop'], dtype=object), array(['Matthew_James'], dtype=object), array(['Andrew_Eleftheriou'], dtype=object), array(['Michael_Phillips'], dtype=object), array(['Noor_Husin'], dtype=object), array(['Josh_Maja'], dtype=object), array(['Ethan_Robson'], dtype=object), array(['Charlie_Rowan'], dtype=object), array(['Harry_Lewis'], dtype=object), array(['Michael_Ledger'], dtype=object), array(['Joey_Barton'], dtype=object), array(['Rudy_Gestede'], dtype=object), array(['Evandro_Goebel'], dtype=object), array(['Joel_Taylor'], dtype=object), array(['Mauro_Zarate'], dtype=object), array(["M'Baye_Niang"], dtype=object), array(["Alfred_N'Diaye"], dtype=object), array(['Molla_Wague'], dtype=object), array(['Baily_Cargill'], dtype=object), array(['Mouez_Hassen'], dtype=object), array(['Daniel_Agyei'], dtype=object), array(['Martin_Caceres'], dtype=object), array(['Harry_Wilson'], dtype=object), array(['Joe_Williams'], dtype=object), array(['Dion_Pereira'], dtype=object), array(['James_Husband'], dtype=object), array(['Eduardo_Dos Reis Carvalho'], dtype=object), array(['Nathan_Holland'], dtype=object), array(['Rhian_Brewster'], dtype=object), array(['Angus_Gunn'], dtype=object), array(['Demetri_Mitchell'], dtype=object), array(['Elliott_Moore'], dtype=object), array(['Filip_Lesniak'], dtype=object), array(['Samuel_Shashoua'], dtype=object), array(['Zachary_Dearnley'], dtype=object), array(['Daniel_Kemp'], dtype=object), array(['Daniel_Batty'], dtype=object), array(['Matthew_Worthington'], dtype=object), array(['Sam_Surridge'], dtype=object)]

# %%
pname_1718 = pd.read_csv('data/2017-18/player_idlist.csv')
fname = pname_1718['first_name']
sname = pname_1718['second_name']
pname_1718 = fname + '_' + sname

print pname_1718

pname_pos_team_1718 = pd.read_csv('data/Player_Pos_Team_2017-18.csv', skiprows=None)
fname = pname_pos_team_1718['FirstName']
sname = pname_pos_team_1718['Surname']
pname_pos_team_1718_name = fname + '_' + sname


count = 0
for st in pname_1718.values:
    if st not in pname_pos_team_1718_name.values:
        print st
        count += 1

print count
#print pname_pos_team
#print pname_1718.values
#f2 = unicode(f, "utf-8")

# player_list = []

# count = 0
# for i in pname_pos_team_1718.index:
#     player_name = pname_pos_team_1718.loc[i]['FirstName'] + '_' + pname_pos_team_1718.loc[i]['Surname']
#     player_list.append(player_name)
#     if(player_name not in pname_1718.values):
#         #print player_name
#         count += 1

#print player_list
#print count
# Out:
# 0                  David_Ospina
# 1                     Petr_Cech
# 2      Damian Emiliano_Martinez
# 3             Laurent_Koscielny
# 4               Per_Mertesacker
# 5      Gabriel Armando_de Abreu
# 6               Héctor_Bellerín
# 7                  Kieran_Gibbs
# 8                Carl_Jenkinson
# 9                 Nacho_Monreal
# 10                  Rob_Holding
# 11             Shkodran_Mustafi
# 12               Sead_Kolasinac
# 13               Alexis_Sánchez
# 14                 Theo_Walcott
# 15                   Mesut_Özil
# 16             Santiago_Cazorla
# 17                 Aaron_Ramsey
# 18      Alex_Oxlade-Chamberlain
# 19             Francis_Coquelin
# 20                   Alex_Iwobi
# 21               Mohamed_Elneny
# 22                 Granit_Xhaka
# 23                Jack_Wilshere
# 24               Olivier_Giroud
# 25                Danny_Welbeck
# 26                  Lucas_Pérez
# 27          Alexandre_Lacazette
# 28                Asmir_Begovic
# 29                  Artur_Boruc
#                  ...
# 555              Thomas_Edwards
# 556                 Alex_Palmer
# 557                Ethan_Ampadu
# 558                  Matt_Macey
# 559              Edward_Nketiah
# 560                   Joe_Rodon
# 561                 Julien_Ngoy
# 562              Beni_Baningime
# 563             Mathieu_Debuchy
# 564             Paulo_Gazzaniga
# 565              Alfie_Whiteman
# 566      Antonio_Martinez Lopez
# 567              Domingos_Quina
# 568              Jakob_Haugaard
# 569                Jack_Simpson
# 570             Hamza_Choudhury
# 571               Max_Melbourne
# 572                 Ben_Johnson
# 573                Nathan_Trott
# 574            Fredrik_Ulvestad
# 575                Erwin_Mulder
# 576             Rayhaan_Tulloch
# 577             Nathan_Ferguson
# 578           Aaron_Wan-Bissaka
# 579                Moses_Makasi
# 580              Michael_Folivi
# 581             Daniel_Bachmann
# 582          Callum_Hudson-Odoi
# 583             Emerson_Hyndman
# 584              Connor_Mahoney
# Length: 585, dtype: object
# Fernando Francisco_Reges
# Manuel_Agudo Durán
# 2

# %%
path = 'data/2016-17/players/'
for i in player_avg_history.index:
    f = path + i + '/history.csv'
    f2 = unicode(f, "utf-8") # a shot in the dark; bullseye
    a = pd.read_csv(f2)
    b = a.mean(axis=0)
#     print b[features]
    player_avg_history.loc[i] = b[features]
    player_avg_history.loc[i, 'points_per_min'] = 0 if b['minutes'] == 0 else b['total_points'] / b['minutes']

# %%
player_avg_history[:10]
# Out:
#                            assists     bonus goals_scored start_cost end_cost  \
# David_Ospina                     0  0.666667            0         50       48
# Petr_Cech                 0.181818   3.54545            0    62.7273  61.7273
# Laurent_Koscielny         0.428571   13.1429      2.42857    58.5714  58.7143
# Per_Mertesacker           0.333333   7.66667     0.833333         55     55.5
# Gabriel Armando_de Abreu  0.333333   3.66667     0.333333    51.6667  47.3333
# Héctor_Bellerín                  3      8.75            1       52.5    55.75
# Kieran_Gibbs               1.09091   2.81818     0.181818    51.8182  49.0909
# Mathieu_Debuchy                1.2       2.4          0.4         52     48.6
# Carl_Jenkinson            0.833333       2.5          0.5    49.1667  46.6667
# Nacho_Monreal                    2       7.2          0.2         55       53
#
#                           minutes total_points  points_per_min
# David_Ospina              707.667      32.6667        0.046161
# Petr_Cech                 2699.64      130.818        0.048458
# Laurent_Koscielny         2550.71      117.857        0.046206
# Per_Mertesacker            2206.5      90.6667        0.041091
# Gabriel Armando_de Abreu  1210.33           48        0.039658
# Héctor_Bellerín            1826.5           92        0.050370
# Kieran_Gibbs              846.727      38.0909        0.044986
# Mathieu_Debuchy             923.6         28.8        0.031182
# Carl_Jenkinson             1077.5         39.5        0.036659
# Nacho_Monreal              2137.6         94.4        0.044162

# %%
trainFeature = features[:3]
trainFeature.append(features[5])
x = player_avg_history[trainFeature]
y = player_avg_history['total_points']

# %%
from sklearn import linear_model
regr = linear_model.LinearRegression()
regr.fit(x, y)

path = 'data/2016-17/players/'
player_score = {}
for i in player_avg_history.index:
#     print i
    f = unicode(path + i + '/gw.csv', "utf-8")
    a = pd.read_csv(f)
    a = a[a['minutes']>0]
    b = a[trainFeature][-5:]
#     print b
    c = regr.predict(b).mean() if b.shape[0] > 0 else 0
#     print c
    player_score[i] = c

import operator
sorted_x = sorted(player_score.items(), key=operator.itemgetter(1), reverse=True)
sorted_x[:10]
# Out:
# [('Harry_Kane', 10.994999252850793),
#  ('Alexis_S\xc3\xa1nchez', 9.769062252981664),
#  ('Kevin_De Bruyne', 9.4075367370010063),
#  ('Gabriel Fernando_de Jesus', 9.3409168972958199),
#  ('Fernando_Llorente', 8.9243282570480371),
#  ('Christian_Eriksen', 8.8768222009788325),
#  ('Sergio_Ag\xc3\xbcero', 8.7515936942573855),
#  ('Georginio_Wijnaldum', 7.9762292347018811),
#  ('Jamie_Vardy', 7.8865466886224684),
#  ('Sam_Vokes', 7.8680728401782316)]

# %%
from sklearn.svm import SVR
import numpy as np
clf = SVR(C=1.0, epsilon=0.2)
clf.fit(x, y)

path = 'data/2016-17/players/'
player_score = {}
for i in player_avg_history.index:
#     print i
    f = unicode(path + i + '/gw.csv', "utf-8")
    a = pd.read_csv(f)
    a = a[a['minutes']>0]
    b = a[trainFeature][-5:]
#     print b
    c = clf.predict(b).mean() if b.shape[0] > 0 else 0
#     print c
    player_score[i] = c
    
sorted_x = sorted(player_score.items(), key=operator.itemgetter(1), reverse=True)
sorted_x[:10]
# Out:
# [('Ashley_Barnes', 44.051226468346563),
#  ('Ilkay_G\xc3\xbcndogan', 44.029239382404242),
#  ('Leon_Britton', 43.974050801316629),
#  ('Mauro_Z\xc3\xa1rate', 43.927959616802802),
#  ('Shinji_Okazaki', 43.859312985857301),
#  ('Lee_Cattermole', 43.833647275578848),
#  ('Bojan_Krkic', 43.76950880059993),
#  ('Curtis_Davies', 43.636818521878538),
#  ('Charlie_Austin', 43.584895945601971),
#  ('Steven_Pienaar', 43.486329184018373)]

# %%
clf2 = linear_model.BayesianRidge()
clf2.fit(x,y)

path = 'data/2016-17/players/'
player_score = {}
for i in player_avg_history.index:
#     print i
    f = unicode(path + i + '/gw.csv', "utf-8")
    a = pd.read_csv(f)
    a = a[a['minutes']>0]
    b = a[trainFeature][-5:]
#     print b
    c = clf2.predict(b).mean() if b.shape[0] > 0 else 0
#     print c
    player_score[i] = c
    
sorted_x = sorted(player_score.items(), key=operator.itemgetter(1), reverse=True)
sorted_x[:10]
# Out:
# [('Harry_Kane', 10.994217820991816),
#  ('Alexis_S\xc3\xa1nchez', 9.7757571199733881),
#  ('Kevin_De Bruyne', 9.3987864183259511),
#  ('Gabriel Fernando_de Jesus', 9.3373516511348278),
#  ('Fernando_Llorente', 8.9309544026824543),
#  ('Christian_Eriksen', 8.8744311403925416),
#  ('Sergio_Ag\xc3\xbcero', 8.7504291652068638),
#  ('Georginio_Wijnaldum', 7.976356413911633),
#  ('Jamie_Vardy', 7.8892524663300376),
#  ('Sam_Vokes', 7.8734291708009678)]

# %%
from sklearn.ensemble import RandomForestRegressor
regr = RandomForestRegressor(max_depth=2, random_state=0)
regr.fit(x, y)

path = 'data/2016-17/players/'
player_score = {}
for i in player_avg_history.index:
#     print i
    f = unicode(path + i + '/gw.csv', "utf-8")
    a = pd.read_csv(f)
    a = a[a['minutes']>0]
    b = a[trainFeature][-5:]
#     print b
    c = regr.predict(b).mean() if b.shape[0] > 0 else 0
#     print c
    player_score[i] = c

sorted_x = sorted(player_score.items(), key=operator.itemgetter(1), reverse=True)
sorted_x[:10]
# Out:
# [('Christian_Fuchs', 4.9670230237886175),
#  ('Jan_Vertonghen', 4.9670230237886175),
#  ('Oumar_Niasse', 4.9670230237886175),
#  ('Cesc_F\xc3\xa0bregas', 4.9670230237886175),
#  ('Ahmed_Musa', 4.9670230237886175),
#  ('Antonio_Valencia', 4.9670230237886175),
#  ('Chris_Brunt', 4.9670230237886175),
#  ('Giannelli_Imbula', 4.9670230237886175),
#  ('Jesse_Lingard', 4.9670230237886175),
#  ('Peter_Crouch', 4.9670230237886175)]

# %%
from sklearn import neural_network
clf3 = neural_network.MLPRegressor(
    hidden_layer_sizes=(10,),  activation='relu', solver='adam', alpha=0.001, batch_size='auto',
    learning_rate='constant', learning_rate_init=0.01, power_t=0.5, max_iter=1000, shuffle=True,
    random_state=9, tol=0.0001, verbose=False, warm_start=False, momentum=0.9, nesterovs_momentum=True,
    early_stopping=False, validation_fraction=0.1, beta_1=0.9, beta_2=0.999, epsilon=1e-08)

clf3.fit(x,y)

path = 'data/2016-17/players/'
player_score = {}
for i in player_avg_history.index:
#     print i
    f = unicode(path + i + '/gw.csv', "utf-8")
    a = pd.read_csv(f)
    a = a[a['minutes']>0]
    b = a[trainFeature][-5:]
#     print b
    c = regr.predict(b).mean() if b.shape[0] > 0 else 0
#     print c
    player_score[i] = c

sorted_x = sorted(player_score.items(), key=operator.itemgetter(1), reverse=True)
sorted_x[:10]
# Out:
# [('Christian_Fuchs', 4.9670230237886175),
#  ('Jan_Vertonghen', 4.9670230237886175),
#  ('Oumar_Niasse', 4.9670230237886175),
#  ('Cesc_F\xc3\xa0bregas', 4.9670230237886175),
#  ('Ahmed_Musa', 4.9670230237886175),
#  ('Antonio_Valencia', 4.9670230237886175),
#  ('Chris_Brunt', 4.9670230237886175),
#  ('Giannelli_Imbula', 4.9670230237886175),
#  ('Jesse_Lingard', 4.9670230237886175),
#  ('Peter_Crouch', 4.9670230237886175)]
